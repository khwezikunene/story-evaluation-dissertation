# %% [markdown]
# # UCSD EDA by Khwezi Kunene
# Fantasy and Paranormal books. English reviews only
#
#
# ---
#
# This dataset will explore the input files from https://cseweb.ucsd.edu/~jmcauley/datasets/goodreads.html
#
# Fantasy & Paranormal (258,585 books, 55,397,550 interactions, 3,424,641 detailed reviews)
# - goodreads_books_fantasy_paranormal.json.gz
# - goodreads_interactions_fantasy_paranormal.json.gz
# - goodreads_reviews_fantasy_paranormal.json.gz

# %% [markdown]
# ## Imports and Data Loading

# %%
import json
import re
from collections import Counter
from tqdm import tqdm
from pathlib import Path
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
from scipy import stats
import nltk
nltk.download('vader_lexicon')
nltk.download('stopwords')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /user/HS402/kk01697/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /user/HS402/kk01697/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
books_file = "/user/HS402/kk01697/Documents/dissertation/story-evaluation-dissertation/data/raw/goodreads/goodreads_books_fantasy_paranormal.json"
reviews_file = "/user/HS402/kk01697/Documents/dissertation/story-evaluation-dissertation/data/raw/goodreads/goodreads_reviews_fantasy_paranormal.json"

# %%
reviews = []

with open(reviews_file, "r") as f:
    for line in tqdm(f):
        reviews.append(json.loads(line))
review_df = pd.DataFrame(reviews)
print(review_df.shape)
review_df.head()
# Out:
# 3424641it [00:09, 352235.46it/s]
# (3424641, 11)
#                             user_id   book_id  \
# 0  8842281e1d1347389f2ab93d60773d4d  18245960
# 1  8842281e1d1347389f2ab93d60773d4d   5577844
# 2  8842281e1d1347389f2ab93d60773d4d  17315048
# 3  8842281e1d1347389f2ab93d60773d4d  13453029
# 4  8842281e1d1347389f2ab93d60773d4d  13239822
#
#                           review_id  rating  \
# 0  dfdbb7b0eb5a7e4c26d59a937e2e5feb       5
# 1  52c8ac49496c153e4a97161e36b2db55       5
# 2  885c772fb033b041f42d57cef5be0a43       5
# 3  46a6e1a14e8afc82d221fec0a2bd3dd0       4
# 4  a582bfa8efd69d453a5a21a678046b36       3
#
#                                          review_text  \
# 0  This is a special book. It started slow for ab...
# 1  A beautiful story. Neil Gaiman is truly a uniq...
# 2  Mark Watney is a steely-eyed missile man. A ma...
# 3  A fun fast paced book that sucks you in right ...
# 4  This book has a great premise, and is full of ...
#
#                        date_added                    date_updated  \
# 0  Sun Jul 30 07:44:10 -0700 2017  Wed Aug 30 00:00:26 -0700 2017
# 1  Wed Sep 24 09:29:29 -0700 2014  Wed Oct 01 00:31:56 -0700 2014
# 2  Sat Apr 05 09:30:53 -0700 2014  Wed Mar 22 11:33:10 -0700 2017
# 3  Tue Dec 04 11:12:22 -0800 2012  Sat Jul 26 11:43:28 -0700 2014
# 4  Mon Jul 02 16:04:16 -0700 2012  Wed Mar 22 11:32:20 -0700 2017
#
#                           read_at                      started_at  n_votes  \
# 0  Sat Aug 26 12:05:52 -0700 2017  Tue Aug 15 13:23:18 -0700 2017       28
# 1  Tue Sep 30 00:00:00 -0700 2014  Sun Sep 21 00:00:00 -0700 2014        5
# 2  Mon Aug 25 00:00:00 -0700 2014  Sat Aug 16 00:00:00 -0700 2014       25
# 3  Tue Jul 08 00:00:00 -0700 2014  Wed Jul 02 00:00:00 -0700 2014        5
# 4  Wed Aug 15 00:00:00 -0700 2012  Sun Aug 12 00:00:00 -0700 2012        7
#
#    n_comments
# 0           1
# 1           1
# 2           5
# 3           1
# 4           0

# %%
books = []

with open(books_file, "r") as f:
    for line in tqdm(f):
        books.append(json.loads(line))
book_df = pd.DataFrame(books)
print(book_df.shape)
book_df.head()
# Out:
# 258585it [00:09, 26867.00it/s]
# (258585, 29)
#          isbn text_reviews_count     series country_code language_code  \
# 0                              7   [189911]           US           eng
# 1  1934876569                  6   [151854]           US
# 2                             60  [1052227]           US           eng
# 3                              1   [147734]           US
# 4                             21   [811663]           US         en-US
#
#                                      popular_shelves        asin is_ebook  \
# 0  [{'count': '58', 'name': 'to-read'}, {'count':...  B00071IKUY    false
# 1  [{'count': '515', 'name': 'to-read'}, {'count'...                false
# 2  [{'count': '54', 'name': 'currently-reading'},...  B01NCIKAQX     true
# 3  [{'count': '1057', 'name': 'to-read'}, {'count...  B0056A00P4     true
# 4  [{'count': '598', 'name': 'to-read'}, {'count'...  B01BLJGA9S     true
#
#   average_rating kindle_asin  ... publication_month edition_information  \
# 0           4.03              ...                     Book Club Edition
# 1           4.22              ...                 3
# 2           4.33  B01NCIKAQX  ...
# 3           4.04  B0056A00P4  ...
# 4           4.23  B01BLJGA9S  ...
#
#   publication_year                                                url  \
# 0             1987  https://www.goodreads.com/book/show/7327624-th...
# 1             2009  https://www.goodreads.com/book/show/6066812-al...
# 2                   https://www.goodreads.com/book/show/33394837-t...
# 3                   https://www.goodreads.com/book/show/12182387-t...
# 4                   https://www.goodreads.com/book/show/29074693-p...
#
#                                            image_url   book_id ratings_count  \
# 0  https://images.gr-assets.com/books/1304100136m...   7327624           140
# 1  https://images.gr-assets.com/books/1316637798m...   6066812            98
# 2  https://images.gr-assets.com/books/1493114742m...  33394837           269
# 3  https://s.gr-assets.com/assets/nophoto/book/11...  12182387             4
# 4  https://s.gr-assets.com/assets/nophoto/book/11...  29074693           149
#
#     work_id                                              title  \
# 0   8948723  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 1    701117  All's Fairy in Love and War (Avalon: Web of Ma...
# 2  54143148            The House of Memory (Pluto's Snitch #2)
# 3    285263                     The Passion (Dark Visions, #3)
# 4  46079519              Prowled Darkness (Dante's Circle, #7)
#
#                                 title_without_series
# 0  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 1  All's Fairy in Love and War (Avalon: Web of Ma...
# 2            The House of Memory (Pluto's Snitch #2)
# 3                     The Passion (Dark Visions, #3)
# 4              Prowled Darkness (Dante's Circle, #7)
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Merge books and reviews

# %%
def merge(review_df, book_df):
    merged = review_df.merge(book_df, on='book_id', how='inner')
    print("Merged shape:", merged.shape)
    return merged

# %% [markdown]
# ## Ratings and Reviews

# %%
def rating_distribution(df):

    plt.figure(figsize=(7,5))
    sns.countplot(data=df, x='rating')

    plt.title("Review Ratings")
    plt.xlabel("Rating")
    plt.ylabel("Count")

    plt.show()

    print(df['rating'].describe())

# %%
def review_length_analysis(df):
    df = df.copy()
    df['review_length'] = (df['review_text'].astype(str).str.split().str.len())
    print(df['review_length'].describe())
    
    plt.figure(figsize=(8,5))
    sns.histplot(df['review_length'],bins=50)

    plt.title("Review Length")
    plt.show()

    return df

# %%
def review_length_vs_rating(df):
    plt.figure(figsize=(8,5))
    sns.boxplot(data=df, x='rating',y='review_length')
    plt.title("Review Length by Rating")
    plt.show()

# %%
def popularity_analysis(df):
    plt.figure(figsize=(8,5))
    sns.histplot(np.log1p(df['ratings_count']),bins=40)
    plt.title("Book Popularity")
    plt.xlabel("Log Ratings Count")
    plt.show()
    print(df['ratings_count'].describe())

# %%
def reviews_per_book(df):
    counts = (df.groupby('book_id').size())
    print(counts.describe())
    plt.figure(figsize=(8,5))
    sns.histplot(counts,bins=50)
    plt.xlim(0,100)
    plt.title("Reviews per Book")
    plt.show()

# %%
def average_rating_analysis(df):
    plt.figure(figsize=(8,5))
    sns.histplot(df['average_rating'].astype(float), bins=30)

    plt.title("Book Average Rating")
    plt.show()

    print(df['average_rating'].describe())

# %%
def correlation_analysis(df):
    cols = ['average_rating', 'ratings_count', 'text_reviews_count', 'n_votes', 'review_length']
    corr = (df[cols].corr())

    plt.figure(figsize=(8,6))

    sns.heatmap(corr,annot=True,cmap='Blues')

    plt.title("Feature Correlations")
    plt.show()

# %% [markdown]
# ## Run EDA

# %%
fan_df = merge(review_df, book_df)
# Out:
# Merged shape: (2909766, 39)

# %%
rating_distribution(fan_df)
# Out:
# count    2.909766e+06
# mean     3.830897e+00
# std      1.245130e+00
# min      0.000000e+00
# 25%      3.000000e+00
# 50%      4.000000e+00
# 75%      5.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
review_length_analysis(fan_df)
# Out:
# count    2.909766e+06
# mean     1.384299e+02
# std      1.963537e+02
# min      0.000000e+00
# 25%      2.300000e+01
# 50%      6.500000e+01
# 75%      1.730000e+02
# max      6.664000e+03
# Name: review_length, dtype: float64
#                                   user_id   book_id  \
# 0        8842281e1d1347389f2ab93d60773d4d  18245960
# 1        8842281e1d1347389f2ab93d60773d4d   5577844
# 2        8842281e1d1347389f2ab93d60773d4d  17315048
# 3        8842281e1d1347389f2ab93d60773d4d  13453029
# 4        8842281e1d1347389f2ab93d60773d4d  13239822
# ...                                   ...       ...
# 2909761  9a1e8a72fadaa8f3038aa783114e12cc      5907
# 2909762  a13e16a58266ffa4a0851c417c4cda8f   6137154
# 2909763  007c41115862813421ff17dde43728b3     41804
# 2909764  fc5aea6994fc754daefa27cbea10ac79  14740456
# 2909765  d0f6d1a4edcab80a6010cfcfeda4999f   1656001
#
#                                 review_id  rating  \
# 0        dfdbb7b0eb5a7e4c26d59a937e2e5feb       5
# 1        52c8ac49496c153e4a97161e36b2db55       5
# 2        885c772fb033b041f42d57cef5be0a43       5
# 3        46a6e1a14e8afc82d221fec0a2bd3dd0       4
# 4        a582bfa8efd69d453a5a21a678046b36       3
# ...                                   ...     ...
# 2909761  21ad3306ba94d6af0c3e343b898c3540       5
# 2909762  1f6fc20b8187e8f36e12daf947b13e66       5
# 2909763  45064afd7417da54acabb4db65af7d28       4
# 2909764  b048505c5b1e9ab8695afa3edce1b5d9       4
# 2909765  b3d9a00405f7e96752d67b85deda4c7d       4
#
#                                                review_text  \
# 0        This is a special book. It started slow for ab...
# 1        A beautiful story. Neil Gaiman is truly a uniq...
# 2        Mark Watney is a steely-eyed missile man. A ma...
# 3        A fun fast paced book that sucks you in right ...
# 4        This book has a great premise, and is full of ...
# ...                                                    ...
# 2909761                                           I like..
# 2909762  A really amazing book! It goes great with Grac...
# 2909763                                               joss
# 2909764  I generally liked the book. It had some parts ...
# 2909765  I started the first chapter, can't seem to get...
#
#                              date_added                    date_updated  \
# 0        Sun Jul 30 07:44:10 -0700 2017  Wed Aug 30 00:00:26 -0700 2017
# 1        Wed Sep 24 09:29:29 -0700 2014  Wed Oct 01 00:31:56 -0700 2014
# 2        Sat Apr 05 09:30:53 -0700 2014  Wed Mar 22 11:33:10 -0700 2017
# 3        Tue Dec 04 11:12:22 -0800 2012  Sat Jul 26 11:43:28 -0700 2014
# 4        Mon Jul 02 16:04:16 -0700 2012  Wed Mar 22 11:32:20 -0700 2017
# ...                                 ...                             ...
# 2909761  Mon Mar 17 11:26:01 -0700 2008  Mon Mar 17 11:26:56 -0700 2008
# 2909762  Wed Jun 27 22:11:26 -0700 2012  Wed Jun 27 22:12:45 -0700 2012
# 2909763  Sun Aug 25 01:47:27 -0700 2013  Sun Aug 25 01:47:40 -0700 2013
# 2909764  Sun Feb 03 08:09:36 -0800 2013  Sun Feb 03 17:23:07 -0800 2013
# 2909765  Mon Jun 04 18:08:44 -0700 2012  Tue Jun 26 18:58:46 -0700 2012
#
#                                 read_at                      started_at  \
# 0        Sat Aug 26 12:05:52 -0700 2017  Tue Aug 15 13:23:18 -0700 2017
# 1        Tue Sep 30 00:00:00 -0700 2014  Sun Sep 21 00:00:00 -0700 2014
# 2        Mon Aug 25 00:00:00 -0700 2014  Sat Aug 16 00:00:00 -0700 2014
# 3        Tue Jul 08 00:00:00 -0700 2014  Wed Jul 02 00:00:00 -0700 2014
# 4        Wed Aug 15 00:00:00 -0700 2012  Sun Aug 12 00:00:00 -0700 2012
# ...                                 ...                             ...
# 2909761  Sun Feb 16 00:00:00 -0800 1997
# 2909762
# 2909763
# 2909764
# 2909765                                  Sun Jun 10 00:00:00 -0700 2012
#
#          n_votes  ...  publication_month edition_information publication_year  \
# 0             28  ...                 10                                 2014
# 1              5  ...                 10                                 2009
# 2             25  ...                  3                                 2013
# 3              5  ...                  1                                 2012
# 4              7  ...                  6                                 2012
# ...          ...  ...                ...                 ...              ...
# 2909761        0  ...                  8                                 2002
# 2909762        0  ...                         1st US Edition
# 2909763        0  ...                  6                                 2004
# 2909764        0  ...                  1                  US             2013
# 2909765        0  ...                  5                                 2008
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/18245960-t...
# 1        https://www.goodreads.com/book/show/5577844-st...
# 2        https://www.goodreads.com/book/show/17315048-t...
# 3        https://www.goodreads.com/book/show/13453029-w...
# 4        https://www.goodreads.com/book/show/13239822-a...
# ...                                                    ...
# 2909761  https://www.goodreads.com/book/show/5907.The_H...
# 2909762   https://www.goodreads.com/book/show/6137154-fire
# 2909763  https://www.goodreads.com/book/show/41804.I_Robot
# 2909764  https://www.goodreads.com/book/show/14740456-t...
# 2909765  https://www.goodreads.com/book/show/1656001.Th...
#
#                                                  image_url ratings_count  \
# 0        https://images.gr-assets.com/books/1396560452m...          6336
# 1        https://images.gr-assets.com/books/1328305969m...          4948
# 2        https://images.gr-assets.com/books/1393422559m...          2092
# 3        https://images.gr-assets.com/books/1349614200m...         83601
# 4        https://images.gr-assets.com/books/1325543155m...         11181
# ...                                                    ...           ...
# 2909761  https://images.gr-assets.com/books/1372847500m...       2099680
# 2909762  https://images.gr-assets.com/books/1331535456m...        100435
# 2909763  https://images.gr-assets.com/books/1388321463m...        201196
# 2909764  https://images.gr-assets.com/books/1345047431m...          3441
# 2909765  https://images.gr-assets.com/books/1318009171m...        756375
#
#           work_id                                              title  \
# 0        25696480  The Three-Body Problem (Remembrance of Earth’s...
# 1         3166179                                           Stardust
# 2        21825181                                        The Martian
# 3        18979356                            Wool Omnibus (Silo, #1)
# 4        18330291                                    Alif the Unseen
# ...           ...                                                ...
# 2909761   1540236                                         The Hobbit
# 2909762   6128277                         Fire (Graceling Realm, #2)
# 2909763   1796026                              I, Robot (Robot #0.1)
# 2909764  20386810                            The Prey (The Hunt, #2)
# 2909765   3328799                            The Host (The Host, #1)
#
#                                       title_without_series review_length
# 0        The Three-Body Problem (Remembrance of Earth’s...           365
# 1                                                 Stardust           282
# 2                                              The Martian           275
# 3                                  Wool Omnibus (Silo, #1)           324
# 4                                          Alif the Unseen           314
# ...                                                    ...           ...
# 2909761                                         The Hobbit             2
# 2909762                         Fire (Graceling Realm, #2)            32
# 2909763                              I, Robot (Robot #0.1)             1
# 2909764                            The Prey (The Hunt, #2)            84
# 2909765                            The Host (The Host, #1)            53
#
# [2909766 rows x 40 columns]

# %%
reviews_per_book(fan_df)
# Out:
# count    145537.000000
# mean         19.993308
# std         142.906378
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           9.000000
# max       10535.000000
# dtype: float64

# %%
average_rating_analysis(fan_df)
# Out:
# count     2909766
# unique        312
# top          4.12
# freq        57732
# Name: average_rating, dtype: object

# %%
correlation_analysis(fan_df)
