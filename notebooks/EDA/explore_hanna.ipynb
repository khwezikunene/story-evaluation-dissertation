# %%
import pandas as pd

df = pd.read_csv('../data/raw/hanna/hanna_stories_annotations.csv')
print(df.shape)
df.head()
print(df.columns.tolist())
df[['Relevance','Coherence','Empathy','Surprise','Engagement','Complexity']].describe()
# Out:
# (3168, 15)
# ['Story ID', 'Prompt', 'Human', 'Story', 'Model', 'Relevance', 'Coherence', 'Empathy', 'Surprise', 'Engagement', 'Complexity', 'Worker ID', 'Assignment ID', 'Work time in seconds', 'Name']
#          Relevance    Coherence      Empathy     Surprise   Engagement  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      2.624684     3.149621     2.295455     2.107323     2.675505
# std       1.464747     1.379753     1.122643     1.161631     1.180895
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       1.000000     2.000000     1.000000     1.000000     2.000000
# 50%       2.000000     3.000000     2.000000     2.000000     3.000000
# 75%       4.000000     4.000000     3.000000     3.000000     3.000000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#         Complexity
# count  3168.000000
# mean      2.451705
# std       1.094033
# min       1.000000
# 25%       2.000000
# ...
